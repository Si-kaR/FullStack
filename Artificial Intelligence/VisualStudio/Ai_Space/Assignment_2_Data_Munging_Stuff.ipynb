# %% [markdown]
# <a href="https://colab.research.google.com/github/Si-kaR/Ai_Space/blob/main/Assignment_2_Data_Munging_Stuff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Name : Robert Sika
# ID   : 89212025


# Assignment | Data Munging Stuff
# Due        | 29 Sep 23:59 | Week by 23:59

# Points     | 25
# File types | NO FILE
# Submitting | URL LINK UPLOAD
# Available  | 20 Sep at 11:00 - 29 Sep at 23:59

# %% [markdown]
# Submission Instructions
#
# *    Use the Google Colab Platform for this assignment
# *    Give the instructors permission to edit your Google Colab file at the file-sharing settings: kavutatenda@gmail.com, percy0.brown@gmail.com, kwekuandyamoah@gmail.com.
# *    Submit the Link to the Colab File
# *    Highlight the source code that corresponds to each question below using text/MarkDown on Google Colab
# --      eg,
#         How many bookings of arrestees were made in 2018?
#         source code:                       dataframe[columns].sort_values().

# %%
# import all necessary libraries and resources

import pandas as pd
import numpy as np
import json
import csv

# %%
# Mounting drive into Colab runtime

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#  Reading from the 'arrest_data' csv file
read_arrest_data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/ASSIGNMENTS/COLAB_Assignment_2/Arrest_Data_from_2010_to_Present.csv')


# Calling | Displaying content from the 'arrest_data' file
# Note: Will be displayed as DataFrame
read_arrest_data
# Out:
# <ipython-input-4-161ff1cf11d8>:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   read_arrest_data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/ASSIGNMENTS/COLAB_Assignment_2/Arrest_Data_from_2010_to_Present.csv')
#                               Report ID Arrest Date    Time  Area ID  \
# 0                               4248313  02/24/2015  1310.0     20.0
# 1                             191811472  05/03/2019  1700.0     18.0
# 2                               4254777  02/26/2015  2010.0     19.0
# 3                               5614161  04/29/2019  1040.0      8.0
# 4                               5615197  04/30/2019   615.0      6.0
# ...                                 ...         ...     ...      ...
# 1227516                         5238234  02/20/2018  2140.0      9.0
# 1227517                  "error" : true         NaN     NaN      NaN
# 1227518    "message" : "Internal error"         NaN     NaN      NaN
# ...

# %% [markdown]
# * Amount or Quantity of Data in the file 'arrest_data' does not correspond with what has been displayed here. Why?
# * Will Colab not display everything given how dense the data is?

# %%
read_arrest_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1227521 entries, 0 to 1227520
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   Report ID                 1227521 non-null  object
#  1   Arrest Date               1227517 non-null  object
#  2   Time                      1227322 non-null  float64
#  3   Area ID                   1227517 non-null  float64
#  4   Area Name                 1227517 non-null  object
#  5   Reporting District        1227517 non-null  float64
#  6   Age                       1227517 non-null  float64
#  7   Sex Code                  1227517 non-null  object
#  8   Descent Code              1227517 non-null  object
#  9   Charge Group Code         1139951 non-null  float64
#  10  Charge Group Description  1139515 non-null  object
#  11  Arrest Type Code          1227516 non-null  object
#  12  Charge                    1227516 non-null  object
# ...

# %%
#Read head of dataset
read_arrest_data.head()
# Out:
#    Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  \
# 0    4248313  02/24/2015  1310.0     20.0    Olympic              2022.0
# 1  191811472  05/03/2019  1700.0     18.0  Southeast              1802.0
# 2    4254777  02/26/2015  2010.0     19.0    Mission              1985.0
# 3    5614161  04/29/2019  1040.0      8.0    West LA               842.0
# 4    5615197  04/30/2019   615.0      6.0  Hollywood               663.0
#
#     Age Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 0  37.0        M            H                5.0                 Burglary
# 1  23.0        F            B                NaN                      NaN
# 2  22.0        M            H                6.0                  Larceny
# 3  41.0        M            H                3.0                  Robbery
# 4  27.0        M            O                5.0                 Burglary
#
#   Arrest Type Code     Charge Charge Description  \
# ...

# %%
#Read tail of dataset
read_arrest_data.tail()
# Out:
#                               Report ID Arrest Date    Time  Area ID  \
# 1227516                         5238234  02/20/2018  2140.0      9.0
# 1227517                  "error" : true         NaN     NaN      NaN
# 1227518    "message" : "Internal error"         NaN     NaN      NaN
# 1227519                  "status" : 500         NaN     NaN      NaN
# 1227520                               }         NaN     NaN      NaN
#
#         Area Name  Reporting District   Age Sex Code Descent Code  \
# 1227516  Van Nuys               905.0  17.0        M            H
# 1227517       NaN                 NaN   NaN      NaN          NaN
# 1227518       NaN                 NaN   NaN      NaN          NaN
# 1227519       NaN                 NaN   NaN      NaN          NaN
# 1227520       NaN                 NaN   NaN      NaN          NaN
#
#          Charge Group Code       Charge Group Description Arrest Type Code  \
# ...

# %% [markdown]
# 1. How many bookings of arrestees were made in 2018? [5]?
#
# ∇∇∇
#
# > Indented block
#
#
# - -   Source code :

# %%
# Checking number of bookings in 2018

#  Store arrest_day columns in variable. as well as corresponding rows.
column_dict = {index: value for index, value in enumerate(read_arrest_data['Arrest Date'])}

# Display 'Arrest Date ' column
column_dict
# Out:
# {0: '02/24/2015',
#  1: '05/03/2019',
#  2: '02/26/2015',
#  3: '04/29/2019',
#  4: '04/30/2019',
#  5: '04/30/2019',
#  6: '02/28/2015',
#  7: '02/28/2015',
#  8: '05/01/2019',
#  9: '05/01/2019',
#  10: '03/01/2015',
#  11: '05/02/2019',
#  12: '03/02/2015',
#  13: '04/16/2019',
#  14: '04/26/2019',
#  15: '04/26/2019',
#  16: '04/26/2019',
#  17: '04/27/2019',
#  18: '04/26/2019',
#  19: '04/23/2019',
#  20: '04/23/2019',
#  21: '04/27/2019',
#  22: '04/22/2019',
#  23: '04/22/2019',
#  24: '04/22/2019',
#  25: '04/23/2019',
#  26: '04/23/2019',
#  27: '04/26/2019',
#  28: '04/24/2019',
#  29: '04/25/2019',
#  30: '04/22/2019',
#  31: '04/22/2019',
#  32: '04/25/2019',
#  33: '04/23/2019',
#  34: '04/23/2019',
#  35: '04/25/2019',
#  36: '04/23/2019',
#  37: '04/22/2019',
#  38: '04/25/2019',
#  39: '04/22/2019',
#  40: '04/25/2019',
#  41: '04/22/2019',
#  42: '04/25/2019',
#  43: '04/25/2019',
#  44: '04/27/2019',
#  45: '04/25/2019',
#  46: '04/27/2019',
#  47: '04/25/2019',
# ...

# %%
# Iterate through the column, split the date into three elements at the slashes (/).

# Afterwards, focusing on the years only, we can obtain the years 2018.
# Finally, we can find the length of the 2018s.

# Check for NULL or Nan Values
# If np returnes NOT NULL or NOT Nan, we negate and let display the values that are not Nan


for key, value in column_dict.items():
  if not np.isnan(value):
    value_list = str.split(value, '/')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-0b41e1d2bdba> in <cell line: 10>()
#       9
#      10 for key, value in column_dict.items():
# ---> 11   if not np.isnan(value):
#      12     value_list = str.split(value, '/')
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %% [markdown]
# 2. How many bookings of arrestees were made in each area and which area has the most arrests in 2018?[5]
#
# ∇∇∇
# - -   Source code :

# %%
# Checking number of arrests in each area


# Checking which area has the most arrests in 2018

# %% [markdown]
# 3. There are differences between the average age of an arrestee for the various charge groups. Find the average age of arrestees per each charge group.
#
#
#
# *   Only consider data for 2018
# *   Do not consider "Pre-Delinquency" and "Non-Criminal Detention" as these charge groups are reserved for minors
# *   Exclude any arrests where the charge group description is not known        [5]
#
# ∇∇∇
# - -   Source code :

# %%
# Finding average age of arrestees per each charge group

# %% [markdown]
# 4. What is the 95% quantile of the age of the arrestee in 2018? Only consider the following charge groups for your analysis:
#
# *    Vehicle Theft
# *    Robbery
# *    Burglary
# *    Receive Stolen Property
#
# ∇∇∇
#
# - - Source Code :

# %%
# Finding the 95% quantile of the age of the arrestee in 2018.

# %% [markdown]
# 5. Crime arrest incidents have been dropping over the years. Using a linear regression for the data from 2010 and 2018 (inclusive), predict the number of crime arrests in 2019. Round to the nearest integer. Note, that the data set includes arrests for misdemeanor, felonies, etc.
#
# ∇∇∇
#
# - - Source Code :

# %%
# Focusing on data from 2010 to 2018 (inclusive)
# Predicting the number of crime arrests in 2019.
